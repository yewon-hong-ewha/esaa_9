# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data=raw_data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = df['preTestScore'],
    y = df['postTestScore'],
    s = df['age'],# 점 size
    alpha = 0.5 # 점의 투명도
)
axes1.set_title('preTestScore vs postTestScore : Sized by Age')
axes1.set_xlabel('preTestScore')
axes1.set_ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = df['preTestScore'],
    y = df['postTestScore'],
    s = df['age']*4.5,# 점 size
    alpha = 0.5, # 점의 투명도,
    c=df['female']
)
axes1.set_title('preTestScore vs postTestScore : Sized by Age')
axes1.set_xlabel('preTestScore')
axes1.set_ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ###

# %% [markdown]
# df['post-pre'] = df['postTestScore'] - df['preTestScore']
# df

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([df[df['female'] == '1']['post-pre'],
               df[df['female'] == '0']['post-pre']],
               labels = ['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Post-PreTestscores')
axes1.set_title('Boxplot of Post-PreTestscores by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Post-PreTestscores by Sex')
